# %%
# %sql
-- #/Volumes/train/prectice_data/data/ecommerce_events.json

CREATE OR REPLACE TABLE BRONZE_EVENTS as SELECT * FROM READ_FILES('/Volumes/train/prectice_data/data/ecommerce_events.json',FORMAT =>'JSON');

# %%
# %sql
select schema_of_json('{"name":"john","age":35}');

# %%
# %sql
select * from bronze_events;

# %%
# %sql
describe table bronze_events;

# %%
# %sql
SELECT
  event_id,
  user.name AS user_name,
  user.city AS city,
  payment.method AS payment_method,
  payment.success AS payment_status
FROM bronze_events;

# %%
# %sql
select event_id,user.name AS User_name,explode(items) AS item from bronze_events;

# %%
# %sql
select event_id,user.name As User_name,items.product,items.price from bronze_events

# %%
# %sql
CREATE  OR REPLACE TABLE silver_events As SELECT
event_id,user.id As user_id,user.name As user_name,
user.city As city,items.product,items.price,payment.method AS payment_method ,payment.Success AS payment_success from bronze_events

# %%
# %sql
select * from silver_events;

# %%
# %sql
select count(Distinct user_id) from silver_events;

# %%
# %sql
CREATE OR REPLACE TABLE bronze_raw_json (
  event_id INT,
  payload STRING
);

# %%
# %sql
select * from bronze_raw_json;

# %%
# %sql
select schema_of_json(payload) AS json_schema from bronze_raw_json LIMIT 1;
